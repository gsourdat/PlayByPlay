# %%
import requests
import json

BASE_URL = "https://esports-api.lolesports.com/persisted/gw"
HEADERS = {"x-api-key": "0TvQnueqKa5mxJntVWt0w4LpLfEkrV1Ta8rQBb9Z"}

def get_leagues():
    url = f"{BASE_URL}/getLeagues?hl=fr-FR"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_tournaments_for_league(league_id):
    url = f"{BASE_URL}/getTournamentsForLeague?hl=fr-FR&leagueId={league_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_standings(tournament_id):
    url = f"{BASE_URL}/getStandings?hl=fr-FR&tournamentId={tournament_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_schedule(league_id=None, page_token=None):
    url = f"{BASE_URL}/getSchedule?hl=fr-FR"
    if league_id:
        url += f"&leagueId={league_id}"
    if page_token:
        url += f"&pageToken={page_token}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_live():
    url = f"{BASE_URL}/getLive?hl=fr-FR"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_completed_events(tournament_id=None):
    url = f"{BASE_URL}/getCompletedEvents?hl=fr-FR&tournamentId={tournament_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_event_details(event_id):
    url = f"{BASE_URL}/getEventDetails?hl=fr-FR&id={event_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_games(game_id):
    url = f"{BASE_URL}/getGames?hl=fr-FR&id={game_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_teams(team_id=None):
    url = f"{BASE_URL}/getTeams?hl=fr-FR"
    if team_id:
        url += f"&id={team_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_window2(game_id, starting_time=None):
    url = f"{BASE_URL}/getWindow?gameId={game_id}"
    if starting_time:
        url += f"&startingTime={starting_time}"
    response = requests.get(url, headers=HEADERS)
    return response.json()

def get_window(game_id, starting_time=None):
    url = f"https://feed.lolesports.com/livestats/v1/window/{game_id}"
    if starting_time:
        url += f"?startingTime={starting_time}"
    response = requests.get(url, headers=HEADERS)
    print(response.status_code)
    return response.json()


def get_match_details2(game_id, starting_time=None, participant_ids=None):
    
    url = f"{BASE_URL}/getDetails?gameId={game_id}"
    if starting_time:
        url += f"&startingTime={starting_time}"
    if participant_ids:
        url += f"&participantIds={','.join(map(str, participant_ids))}"
    response = requests.get(url, headers=HEADERS)
    return response.json()


def get_match_details4(game_id, starting_time=None, participant_ids=None):
    url = f"https://feed.lolesports.com/livestats/v1/details/{game_id}"
    response = requests.get(url, headers=HEADERS)
    return response.json()


def get_match_details3(game_id, starting_time=None, participant_ids=None):
    url = f"https://feed.lolesports.com/livestats/v1/details/{game_id}"
    params = {}
    if starting_time:
        params["startingTime"] = starting_time
    #if participant_ids:
    #    params["participantIds"] = ",".join(map(str, participant_ids))
    #    print(params["participantIds"])
    response = requests.get(url, headers=HEADERS, params=params)
     
    # Afficher le texte brut de la réponse pour déboguer
    print(response.text)  
    
    # Essayer de convertir en JSON
    try:
        return response.json()
    except ValueError as e:
        print(f"Erreur lors de la conversion en JSON: {e}")
        return None


from datetime import datetime, timedelta

def round_to_nearest_10_seconds(dt):
    seconds = (dt.second // 10) * 10
    return dt.replace(second=seconds, microsecond=0)

def get_match_details(game_id, starting_time=None, participant_ids=None):
    url = f"https://feed.lolesports.com/livestats/v1/details/{game_id}"
    params = {}
    if starting_time:
        # Convert starting_time to a datetime object
        starting_time_dt = datetime.fromisoformat(starting_time.replace("Z", "+00:00"))
        # Round the time to the nearest 10 seconds
        rounded_time = round_to_nearest_10_seconds(starting_time_dt)
        params["startingTime"] = rounded_time.isoformat().replace("+00:00", "Z")
    if participant_ids:
        params["participantIds"] = ",".join(map(str, participant_ids))
    response = requests.get(url, headers=HEADERS, params=params)
    return response.json()

# %%
get_live()
# Out:
# {'data': {'schedule': {'events': []}}}

# %%
get_window(113990327983174586 )
# Out:
# 200
# {'esportsGameId': '113990327983174586',
#  'esportsMatchId': '113990327983174585',
#  'gameMetadata': {'patchVersion': '15.5.662.5311',
#   'blueTeamMetadata': {'esportsTeamId': '113770064260414203',
#    'participantMetadata': [{'participantId': 1,
#      'esportsPlayerId': '113770053220165987',
#      'summonerName': 'LR Baus',
#      'championId': 'Gragas',
#      'role': 'top'},
#     {'participantId': 2,
#      'esportsPlayerId': '106371041332804856',
#      'summonerName': 'LR Velja',
#      'championId': 'XinZhao',
#      'role': 'jungle'},
#     {'participantId': 3,
#      'esportsPlayerId': '101189645215143141',
#      'summonerName': 'LR Nemesis',
#      'championId': 'Azir',
#      'role': 'mid'},
#     {'participantId': 4,
#      'esportsPlayerId': '101389749297430422',
#      'summonerName': 'LR Crownie',
#      'championId': 'Corki',
#      'role': 'bottom'},
#     {'participantId': 5,
#      'esportsPlayerId': '98767991761835561',
#      'summonerName': 'LR Rekkles',
#      'championId': 'Rell',
#      'role': 'support'}]},
#   'redTeamMetadata': {'esportsTeamId': '105521637552587612',
#    'participantMetadata': [{'participantId': 6,
#      'esportsPlayerId': '105719283417050138',
#      'summonerName': 'TP Kio',
#      'championId': 'Poppy',
#      'role': 'top'},
#     {'participantId': 7,
#      'esportsPlayerId': '105515253867707529',
#      'summonerName': 'TP Manaty',
#      'championId': 'Zyra',
#      'role': 'jungle'},
#     {'participantId': 8,
#      'esportsPlayerId': '105521300963305788',
#      'summonerName': 'TP Peppe',
#      'championId': 'Yone',
#      'role': 'mid'},
#     {'participantId': 9,
#      'esportsPlayerId': '107105627153828391',
#      'summonerName': 'TP Axelent',
#      'championId': 'Ezreal',
#      'role': 'bottom'},
#     {'participantId': 10,
#      'esportsPlayerId': '107065257649242509',
#      'summonerName': 'TP REAVER',
#      'championId': 'Nautilus',
#      'role': 'support'}]}},
#  'frames': [{'rfc460Timestamp': '2025-03-22T16:07:36.316Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.316Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.316Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.316Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.317Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.317Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.336Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.337Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.337Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}},
#   {'rfc460Timestamp': '2025-03-22T16:07:36.337Z',
#    'gameState': 'in_game',
#    'blueTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 1,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 2,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 3,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 4,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 5,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]},
#    'redTeam': {'totalGold': 0,
#     'inhibitors': 0,
#     'towers': 0,
#     'barons': 0,
#     'totalKills': 0,
#     'dragons': [],
#     'participants': [{'participantId': 6,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 7,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 8,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 9,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0},
#      {'participantId': 10,
#       'totalGold': 0,
#       'level': 1,
#       'kills': 0,
#       'deaths': 0,
#       'assists': 0,
#       'creepScore': 0,
#       'currentHealth': 0,
#       'maxHealth': 0}]}}]}

# %%
print(json.dumps(get_standings('113475994398658012')["data"]["standings"][0]["stages"], indent=4))
# Out:
# [
#     {
#         "id": "113476054450034535",
#         "name": "Saison r\u00e9guli\u00e8re",
#         "type": null,
#         "slug": "regular_season",
#         "sections": [
#             {
#                 "name": "Saison r\u00e9guli\u00e8re",
#                 "matches": [
#                     {
#                         "id": "113476054450558827",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558829",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558831",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558833",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558835",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793567806688",
#                                 "slug": "sk-gaming",
#                                 "name": "SK Gaming",
#                                 "code": "SK",
#                                 "image": "http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558837",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558839",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558841",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558843",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558845",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558847",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558849",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558851",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "101383793567806688",
#                                 "slug": "sk-gaming",
#                                 "name": "SK Gaming",
#                                 "code": "SK",
#                                 "image": "http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558853",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558855",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558857",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558859",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793574360315",
#                                 "slug": "rogue",
#                                 "name": "Rogue",
#                                 "code": "RGE",
#                                 "image": "http://static.lolesports.com/teams/1705054928404_RGE.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558861",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558863",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558865",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793567806688",
#                                 "slug": "sk-gaming",
#                                 "name": "SK Gaming",
#                                 "code": "SK",
#                                 "image": "http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558867",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558869",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558871",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558873",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558875",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558877",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793567806688",
#                                 "slug": "sk-gaming",
#                                 "name": "SK Gaming",
#                                 "code": "SK",
#                                 "image": "http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558879",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558881",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558883",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558885",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558887",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "101383793567806688",
#                                 "slug": "sk-gaming",
#                                 "name": "SK Gaming",
#                                 "code": "SK",
#                                 "image": "http://static.lolesports.com/teams/1643979272144_SK_Monochrome.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558889",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558891",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
# ...
#                                 }
#                             },
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558933",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558937",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             },
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558941",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             },
#                             {
#                                 "id": "109637393694097670",
#                                 "slug": "team-heretics-lec",
#                                 "name": "Team Heretics",
#                                 "code": "TH",
#                                 "image": "http://static.lolesports.com/teams/1672933861879_Heretics-Full-Color.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558945",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "99322214695067838",
#                                 "slug": "team-vitality",
#                                 "name": "Team Vitality",
#                                 "code": "VIT",
#                                 "image": "http://static.lolesports.com/teams/1675865863968_Vitality_FullColor.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558947",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 1
#                                 }
#                             },
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 3
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450558953",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             },
#                             {
#                                 "id": "101383793572656373",
#                                 "slug": "giantx-lec",
#                                 "name": "GIANTX",
#                                 "code": "GX",
#                                 "image": "http://static.lolesports.com/teams/1704790322129_GX.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450624493",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 2
#                                 }
#                             },
#                             {
#                                 "id": "107563714667537640",
#                                 "slug": "team-bds",
#                                 "name": "Team BDS",
#                                 "code": "BDS",
#                                 "image": "http://static.lolesports.com/teams/1641292031788_Team_BDSlogo_square.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450624497",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 3
#                                 }
#                             },
#                             {
#                                 "id": "103461966965149786",
#                                 "slug": "mad-lions",
#                                 "name": "Movistar KOI",
#                                 "code": "MKOI",
#                                 "image": "http://static.lolesports.com/teams/1734012609283_MKOI_FullColor_Blue.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 1
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450624503",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 3
#                                 }
#                             },
#                             {
#                                 "id": "98767991866488695",
#                                 "slug": "fnatic",
#                                 "name": "Fnatic",
#                                 "code": "FNC",
#                                 "image": "http://static.lolesports.com/teams/1631819669150_fnc-2021-worlds.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 2
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "113476054450624509",
#                         "state": "completed",
#                         "previousMatchIds": [],
#                         "flags": [
#                             "hasVod",
#                             "isSpoiler"
#                         ],
#                         "teams": [
#                             {
#                                 "id": "98767991926151025",
#                                 "slug": "g2-esports",
#                                 "name": "G2 Esports",
#                                 "code": "G2",
#                                 "image": "http://static.lolesports.com/teams/G2-FullonDark.png",
#                                 "result": {
#                                     "outcome": "loss",
#                                     "gameWins": 0
#                                 }
#                             },
#                             {
#                                 "id": "111692118851466302",
#                                 "slug": "karmine-corp",
#                                 "name": "Karmine Corp",
#                                 "code": "KC",
#                                 "image": "http://static.lolesports.com/teams/1704714951336_KC.png",
#                                 "result": {
#                                     "outcome": "win",
#                                     "gameWins": 3
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "rankings": []
#             }
#         ]
#     }
# ]

# %%
get_tournaments_for_league('98767991302996019')
# Out:
# {'data': {'leagues': [{'tournaments': [{'id': '113487526512660769',
#       'slug': 'lec_summer_2025',
#       'startDate': '2025-07-21',
#       'endDate': '2025-10-05'},
#      {'id': '113487400974323999',
#       'slug': 'lec_spring_2025',
#       'startDate': '2025-03-29',
#       'endDate': '2025-06-08'},
#      {'id': '113475994398658012',
#       'slug': 'lec_winter_2025',
#       'startDate': '2025-01-18',
#       'endDate': '2025-03-02'},
#      {'id': '112869331703771902',
#       'slug': 'lec_season_finals_2024',
#       'startDate': '2024-08-10',
#       'endDate': '2024-09-01'},
#      {'id': '112352881163915249',
#       'slug': 'lec_summer_2024',
#       'startDate': '2024-06-08',
#       'endDate': '2024-07-28'},
#      {'id': '111997906550466231',
#       'slug': 'lec_spring_2024',
#       'startDate': '2024-03-08',
#       'endDate': '2024-04-15'},
#      {'id': '111560983131400452',
#       'slug': 'lec_winter_2024',
#       'startDate': '2024-01-12',
#       'endDate': '2024-02-19'},
#      {'id': '110848560874526298',
#       'slug': 'lec_season_finals_2023',
#       'startDate': '2023-08-17',
#       'endDate': '2023-09-12'},
#      {'id': '110429332688604205',
#       'slug': 'lec_summer_2023',
#       'startDate': '2023-06-15',
#       'endDate': '2023-08-01'},
#      {'id': '109919226376366902',
#       'slug': 'lec_spring_2023',
#       'startDate': '2023-03-08',
#       'endDate': '2023-04-27'},
#      {'id': '109466537705744120',
#       'slug': 'lec_winter_2023',
#       'startDate': '2023-01-19',
#       'endDate': '2023-02-28'},
#      {'id': '108176672283976661',
#       'slug': 'lec_summer_2022',
#       'startDate': '2022-06-16',
#       'endDate': '2022-09-12'},
#      {'id': '107417059262120466',
#       'slug': 'lec_spring_2022',
#       'startDate': '2022-01-01',
#       'endDate': '2022-05-01'},
#      {'id': '106269680921022418',
#       'slug': 'lec_summer_2021',
#       'startDate': '2021-06-11',
#       'endDate': '2021-08-30'},
#      {'id': '105522958532258735',
#       'slug': 'lec_spring_2021',
#       'startDate': '2021-01-04',
#       'endDate': '2021-04-11'},
#      {'id': '104169295253189561',
#       'slug': 'lec_summer_2020',
#       'startDate': '2020-06-11',
#       'endDate': '2020-09-07'},
#      {'id': '103462459318635408',
#       'slug': 'lec_spring_2020',
#       'startDate': '2020-01-24',
#       'endDate': '2020-04-27'},
#      {'id': '109427822736905228',
#       'slug': 'lec_summer_2019',
#       'startDate': '2019-06-07',
#       'endDate': '2019-09-08'},
#      {'id': '109427411147317375',
#       'slug': 'lec_spring_2019',
#       'startDate': '2019-01-18',
#       'endDate': '2019-04-14'},
#      {'id': '109423067696022268',
#       'slug': 'eu_lcs_summer_2018',
#       'startDate': '2018-06-15',
#       'endDate': '2018-09-09'},
#      {'id': '109421587469439501',
#       'slug': 'eu_lcs_spring_2018',
#       'startDate': '2018-01-19',
#       'endDate': '2018-04-08'},
#      {'id': '109407348769591764',
#       'slug': 'eu_lcs_summer_2017',
#       'startDate': '2017-06-01',
#       'endDate': '2017-09-03'},
#      {'id': '109188748532737193',
#       'slug': 'eu_lcs_spring_2017',
#       'startDate': '2017-01-19',
#       'endDate': '2017-04-23'},
#      {'id': '109189749746037163',
#       'slug': 'eu_lcs_summer_2016',
#       'startDate': '2016-06-02',
#       'endDate': '2016-08-28'},
#      {'id': '109188863217118371',
#       'slug': 'eu_lcs_spring_2016',
#       'startDate': '2016-01-14',
#       'endDate': '2016-04-17'},
#      {'id': '109218068328726599',
#       'slug': 'eu_lcs_summer_2015',
#       'startDate': '2015-05-28',
#       'endDate': '2015-08-23'},
#      {'id': '109212709764395955',
#       'slug': 'eu_lcs_spring_2015',
#       'startDate': '2015-01-22',
#       'endDate': '2015-04-19'},
#      {'id': '109229629611154474',
#       'slug': 'eu_lcs_summer_2014',
#       'startDate': '2014-05-20',
#       'endDate': '2014-08-17'},
#      {'id': '109218949924663566',
#       'slug': 'eu_lcs_spring_2014',
#       'startDate': '2014-01-14',
#       'endDate': '2014-04-17'},
#      {'id': '109349946712116171',
#       'slug': 'eu_lcs_summer_2013',
#       'startDate': '2013-06-14',
#       'endDate': '2022-08-26'},
#      {'id': '109274702204084948',
#       'slug': 'eu_lcs_spring_2013',
#       'startDate': '2013-02-08',
#       'endDate': '2013-04-29'}]}]}}

# %%
get_event_details('113990327983174555')
# Out:
# {'data': {'event': {'id': '113990327983174555',
#    'type': 'match',
#    'tournament': {'id': '113990292491935482'},
#    'league': {'id': '100695891328981122',
#     'slug': 'emea_masters',
#     'image': 'http://static.lolesports.com/leagues/1669375535108_EM_Icon_Green1.png',
#     'name': 'EMEA Masters'},
#    'match': {'strategy': {'count': 5},
#     'teams': [{'id': '107128093558481418',
#       'name': 'ZennIT',
#       'code': 'ZNT',
#       'image': 'http://static.lolesports.com/teams/1671442841824_ZennIT.png',
#       'result': {'gameWins': 1}},
#      {'id': '105515219038427019',
#       'name': 'Karmine Corp Blue',
#       'code': 'KCB',
#       'image': 'http://static.lolesports.com/teams/LFL-KC-logo.png',
#       'result': {'gameWins': 3}}],
#     'games': [{'number': 1,
#       'id': '113990327983174556',
#       'state': 'completed',
#       'teams': [{'id': '107128093558481418', 'side': 'blue'},
#        {'id': '105515219038427019', 'side': 'red'}],
#       'vods': [{'id': '114200105928832386',
#         'parameter': 'iKPj3dxcVTY',
#         'locale': 'fr-FR',
#         'mediaLocale': {'locale': 'fr-FR',
#          'englishName': 'French (France)',
#          'translatedName': 'Français'},
#         'provider': 'youtube',
#         'offset': 0,
#         'firstFrameTime': '2025-03-20T15:17:23.724Z',
#         'startMillis': 1844000,
#         'endMillis': 5763000}]},
#      {'number': 2,
#       'id': '113990327983174557',
#       'state': 'completed',
#       'teams': [{'id': '107128093558481418', 'side': 'blue'},
#        {'id': '105515219038427019', 'side': 'red'}],
#       'vods': [{'id': '114200105917348349',
#         'parameter': 'iKPj3dxcVTY',
#         'locale': 'fr-FR',
#         'mediaLocale': {'locale': 'fr-FR',
#          'englishName': 'French (France)',
#          'translatedName': 'Français'},
#         'provider': 'youtube',
#         'offset': 0,
#         'firstFrameTime': '2025-03-20T15:17:23.724Z',
#         'startMillis': 5821000,
#         'endMillis': 8616000}]},
#      {'number': 3,
#       'id': '113990327983174558',
#       'state': 'completed',
#       'teams': [{'id': '105515219038427019', 'side': 'blue'},
#        {'id': '107128093558481418', 'side': 'red'}],
#       'vods': [{'id': '114200105930470787',
#         'parameter': 'iKPj3dxcVTY',
#         'locale': 'fr-FR',
#         'mediaLocale': {'locale': 'fr-FR',
#          'englishName': 'French (France)',
#          'translatedName': 'Français'},
#         'provider': 'youtube',
#         'offset': 0,
#         'firstFrameTime': '2025-03-20T15:17:23.724Z',
#         'startMillis': 8659000,
#         'endMillis': 11310000}]},
#      {'number': 4,
#       'id': '113990327983174559',
#       'state': 'completed',
#       'teams': [{'id': '105515219038427019', 'side': 'blue'},
#        {'id': '107128093558481418', 'side': 'red'}],
#       'vods': [{'id': '114200105920097027',
#         'parameter': 'iKPj3dxcVTY',
#         'locale': 'fr-FR',
#         'mediaLocale': {'locale': 'fr-FR',
#          'englishName': 'French (France)',
#          'translatedName': 'Français'},
#         'provider': 'youtube',
#         'offset': 0,
#         'firstFrameTime': '2025-03-20T15:17:23.724Z',
#         'startMillis': 11354000,
#         'endMillis': 16944000}]},
#      {'number': 5,
#       'id': '113990327983174560',
#       'state': 'unneeded',
#       'teams': [{'id': '105515219038427019', 'side': 'blue'},
#        {'id': '107128093558481418', 'side': 'red'}],
#       'vods': []}]},
#    'streams': []}}}

# %%
from datetime import datetime, timezone
from collections import Counter

def detect_events(prev_state, curr_state):
    events = []
    timer = curr_state["rfc460Timestamp"]  # Timestamp actuel
    
    for team_color in ["blueTeam", "redTeam"]:
        opponent_team_color = "redTeam" if team_color == "blueTeam" else "blueTeam"
        
        for player in curr_state[team_color]["participants"]:
            player_id = player["esportsPlayerId"]
            prev_player = next((p for p in prev_state[team_color]["participants"] if p["esportsPlayerId"] == player_id), None)
            
            if prev_player and player["kills"] > prev_player["kills"]:
                # Identifier l'adversaire mort
                opponent_player_id = None
                for opponent in curr_state[opponent_team_color]["participants"]:
                    prev_opponent = next((p for p in prev_state[opponent_team_color]["participants"] if p["esportsPlayerId"] == opponent["esportsPlayerId"]), None)
                    if prev_opponent and opponent["deaths"] > prev_opponent["deaths"]:
                        opponent_player_id = opponent["esportsPlayerId"]
                        break
                
                event = {
                    "timer": curr_state["rfc460Timestamp"],
                    "type": "kill",
                    "team_color": team_color,
                    "team_id": curr_state[team_color]["esportsTeamId"],
                    "player_id": player_id,
                    "opponent_team_color": opponent_team_color,
                    "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                    "opponent_player_id": opponent_player_id,  # Adversaire identifié
                    "game_id": prev_state["esportsGameId"],
                    "match_id": prev_state["esportsMatchId"]
                }
                events.append(event)

   

    # Vérifier les tours tombées
    for team_color in ["blueTeam", "redTeam"]:
        prev_towers = prev_state[team_color]["towers"]
        curr_towers = curr_state[team_color]["towers"]
        if curr_towers < prev_towers:
            events.append({
                "timer": timer,
                "type": "tower_fall",
                "team_color": team_color,
                "team_id": curr_state[team_color]["esportsTeamId"],
                "player_id": None,
                "opponent_team_color": opponent_team_color,
                "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                "opponent_player_id": None,  # Adversaire identifié
                "game_id": prev_state["esportsGameId"],
                "match_id": prev_state["esportsMatchId"]
            })

    # Vérifier les inhibiteurs tombés
    for team_color in ["blueTeam", "redTeam"]:
        prev_inhibitors = prev_state[team_color]["inhibitors"]
        curr_inhibitors = curr_state[team_color]["inhibitors"]
        if curr_inhibitors < prev_inhibitors:
            events.append({
                "timer": timer,
                "type": "inhibitor_fall",
                "team_color": team_color,
                "team_id": curr_state[team_color]["esportsTeamId"],
                "player_id": None,
                "opponent_team_color": opponent_team_color,
                "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                "opponent_player_id": None,  # Adversaire identifié
                "game_id": prev_state["esportsGameId"],
                "match_id": prev_state["esportsMatchId"]
            })

    # Vérifier les barons tués
    for team_color in ["blueTeam", "redTeam"]:
        prev_barons = prev_state[team_color]["barons"]
        curr_barons = curr_state[team_color]["barons"]
        if curr_barons > prev_barons:
            events.append({
                "timer": timer,
                "type": "baron",
                "team_color": team_color,
                "team_id": curr_state[team_color]["esportsTeamId"],
                "player_id": None,
                "opponent_team_color": opponent_team_color,
                "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                "opponent_player_id": None,  # Adversaire identifié
                "game_id": prev_state["esportsGameId"],
                "match_id": prev_state["esportsMatchId"]
            })

    # Vérifier les dragons tués
    for team_color in ["blueTeam", "redTeam"]:
        prev_count = Counter(prev_state[team_color]["dragons"])
        curr_count = Counter(curr_state[team_color]["dragons"])
    
        new_dragons = []
    
        for dragon, count in curr_count.items():
            if count > prev_count.get(dragon, 0):  # Vérifie s'il y a plus d'occurrences dans curr
                new_dragons.append(dragon)
        #prev_dragons = set(prev_state[team_color]["dragons"])
        #curr_dragons = set(curr_state[team_color]["dragons"])
        #new_dragons = list(curr_dragons - prev_dragons)
        for dragon in new_dragons:
            events.append({
                "timer": timer,
                "type": dragon + " drake",
                "team_color": team_color,
                "team_id": curr_state[team_color]["esportsTeamId"],
                "player_id": None,
                "opponent_team_color": opponent_team_color,
                "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                "opponent_player_id": None,  # Adversaire identifié
                "game_id": prev_state["esportsGameId"],
                "match_id": prev_state["esportsMatchId"]
            })
            
    if(curr_state["gameState"]=='finished'):
        events.append({
                "timer": timer,
                "type": "Game ended",
                "team_color": team_color,
                "team_id": curr_state[team_color]["esportsTeamId"],
                "player_id": None,
                "opponent_team_color": opponent_team_color,
                "opponent_team_id": curr_state[opponent_team_color]["esportsTeamId"],
                "opponent_player_id": None,  # Adversaire identifié
                "game_id": prev_state["esportsGameId"],
                "match_id": prev_state["esportsMatchId"]
            })

    return events


frame1 = {
            "rfc460Timestamp": "2025-03-20T19:07:39.902Z",
            "gameState": "in_game",
            "blueTeam": {
                "totalGold": 53699,
                "inhibitors": 1,
                "towers": 10,
                "barons": 0,
                "totalKills": 30,
                "dragons": [
                    "mountain",
                    "chemtech"
                ],
                "participants": [
                    {
                        "participantId": 1,
                        "totalGold": 11869,
                        "level": 16,
                        "kills": 4,
                        "deaths": 0,
                        "assists": 4,
                        "creepScore": 233,
                        "currentHealth": 2383,
                        "maxHealth": 3893,
                        "esportsPlayerId": "105700869624784693",
                        "summonerName": "KCB Maynter",
                        "championId": "Renekton",
                        "role": "top"
                    },
                    {
                        "participantId": 2,
                        "totalGold": 11326,
                        "level": 14,
                        "kills": 12,
                        "deaths": 1,
                        "assists": 10,
                        "creepScore": 147,
                        "currentHealth": 0,
                        "maxHealth": 2962,
                        "esportsPlayerId": "107464179845128878",
                        "summonerName": "KCB ISMA",
                        "championId": "Nocturne",
                        "role": "jungle"
                    },
                    {
                        "participantId": 3,
                        "totalGold": 10461,
                        "level": 15,
                        "kills": 7,
                        "deaths": 1,
                        "assists": 7,
                        "creepScore": 204,
                        "currentHealth": 1725,
                        "maxHealth": 2844,
                        "esportsPlayerId": "106302003665923326",
                        "summonerName": "KCB SlowQ",
                        "championId": "Akali",
                        "role": "mid"
                    },
                    {
                        "participantId": 4,
                        "totalGold": 12850,
                        "level": 15,
                        "kills": 7,
                        "deaths": 0,
                        "assists": 16,
                        "creepScore": 231,
                        "currentHealth": 2183,
                        "maxHealth": 2183,
                        "esportsPlayerId": "113741971222479798",
                        "summonerName": "KCB 3XA",
                        "championId": "Aphelios",
                        "role": "bottom"
                    },
                    {
                        "participantId": 5,
                        "totalGold": 7193,
                        "level": 12,
                        "kills": 0,
                        "deaths": 1,
                        "assists": 26,
                        "creepScore": 19,
                        "currentHealth": 1595,
                        "maxHealth": 2368,
                        "esportsPlayerId": "109710705987430108",
                        "summonerName": "KCB Nsurr",
                        "championId": "Karma",
                        "role": "support"
                    }
                ],
                "esportsTeamId": "105515219038427019"
            },
            "redTeam": {
                "totalGold": 36302,
                "inhibitors": 0,
                "towers": 1,
                "barons": 0,
                "totalKills": 3,
                "dragons": [
                    "cloud"
                ],
                "participants": [
                    {
                        "participantId": 6,
                        "totalGold": 9820,
                        "level": 14,
                        "kills": 2,
                        "deaths": 4,
                        "assists": 1,
                        "creepScore": 195,
                        "currentHealth": 0,
                        "maxHealth": 2770,
                        "esportsPlayerId": "110467144044264674",
                        "summonerName": "ZNT Whip",
                        "championId": "Garen",
                        "role": "top"
                    },
                    {
                        "participantId": 7,
                        "totalGold": 6562,
                        "level": 12,
                        "kills": 0,
                        "deaths": 4,
                        "assists": 2,
                        "creepScore": 130,
                        "currentHealth": 0,
                        "maxHealth": 3639,
                        "esportsPlayerId": "107693484400882014",
                        "summonerName": "ZNT shibi",
                        "championId": "Sejuani",
                        "role": "jungle"
                    },
                    {
                        "participantId": 8,
                        "totalGold": 7519,
                        "level": 12,
                        "kills": 1,
                        "deaths": 7,
                        "assists": 1,
                        "creepScore": 156,
                        "currentHealth": 611,
                        "maxHealth": 2188,
                        "esportsPlayerId": "109146898089227862",
                        "summonerName": "ZNT Marty",
                        "championId": "Neeko",
                        "role": "mid"
                    },
                    {
                        "participantId": 9,
                        "totalGold": 7135,
                        "level": 12,
                        "kills": 0,
                        "deaths": 8,
                        "assists": 2,
                        "creepScore": 168,
                        "currentHealth": 1479,
                        "maxHealth": 1843,
                        "esportsPlayerId": "112458338268604979",
                        "summonerName": "ZNT Afriibi",
                        "championId": "Draven",
                        "role": "bottom"
                    },
                    {
                        "participantId": 10,
                        "totalGold": 5266,
                        "level": 10,
                        "kills": 0,
                        "deaths": 7,
                        "assists": 2,
                        "creepScore": 23,
                        "currentHealth": 630,
                        "maxHealth": 1976,
                        "esportsPlayerId": "110494684110133175",
                        "summonerName": "ZNT J3rkie",
                        "championId": "Renata",
                        "role": "support"
                    }
                ],
                "esportsTeamId": "107128093558481418"
            },
            "esportsGameId": "113990327983174559",
            "esportsMatchId": "113990327983174555"
        }

frame2 = {
            "rfc460Timestamp": "2025-03-20T19:07:39.902Z",
            "gameState": "in_game",
            "blueTeam": {
                "totalGold": 53699,
                "inhibitors": 1,
                "towers": 10,
                "barons": 0,
                "totalKills": 30,
                "dragons": [
                    "mountain",
                    "chemtech"
                ],
                "participants": [
                    {
                        "participantId": 1,
                        "totalGold": 11869,
                        "level": 16,
                        "kills": 4,
                        "deaths": 0,
                        "assists": 4,
                        "creepScore": 233,
                        "currentHealth": 2383,
                        "maxHealth": 3893,
                        "esportsPlayerId": "105700869624784693",
                        "summonerName": "KCB Maynter",
                        "championId": "Renekton",
                        "role": "top"
                    },
                    {
                        "participantId": 2,
                        "totalGold": 11326,
                        "level": 14,
                        "kills": 12,
                        "deaths": 1,
                        "assists": 10,
                        "creepScore": 147,
                        "currentHealth": 0,
                        "maxHealth": 2962,
                        "esportsPlayerId": "107464179845128878",
                        "summonerName": "KCB ISMA",
                        "championId": "Nocturne",
                        "role": "jungle"
                    },
                    {
                        "participantId": 3,
                        "totalGold": 10461,
                        "level": 15,
                        "kills": 7,
                        "deaths": 1,
                        "assists": 7,
                        "creepScore": 204,
                        "currentHealth": 1725,
                        "maxHealth": 2844,
                        "esportsPlayerId": "106302003665923326",
                        "summonerName": "KCB SlowQ",
                        "championId": "Akali",
                        "role": "mid"
                    },
                    {
                        "participantId": 4,
                        "totalGold": 12850,
                        "level": 15,
                        "kills": 7,
                        "deaths": 1,
                        "assists": 16,
                        "creepScore": 231,
                        "currentHealth": 2183,
                        "maxHealth": 2183,
                        "esportsPlayerId": "113741971222479798",
                        "summonerName": "KCB 3XA",
                        "championId": "Aphelios",
                        "role": "bottom"
                    },
                    {
                        "participantId": 5,
                        "totalGold": 7193,
                        "level": 12,
                        "kills": 0,
                        "deaths": 1,
                        "assists": 26,
                        "creepScore": 19,
                        "currentHealth": 1595,
                        "maxHealth": 2368,
                        "esportsPlayerId": "109710705987430108",
                        "summonerName": "KCB Nsurr",
                        "championId": "Karma",
                        "role": "support"
                    }
                ],
                "esportsTeamId": "105515219038427019"
            },
            "redTeam": {
                "totalGold": 36302,
                "inhibitors": 0,
                "towers": 1,
                "barons": 0,
                "totalKills": 4,
                "dragons": [
                    "cloud",
                    "hextech"
                ],
                "participants": [
                    {
                        "participantId": 6,
                        "totalGold": 9820,
                        "level": 14,
                        "kills": 3,
                        "deaths": 4,
                        "assists": 1,
                        "creepScore": 195,
                        "currentHealth": 0,
                        "maxHealth": 2770,
                        "esportsPlayerId": "110467144044264674",
                        "summonerName": "ZNT Whip",
                        "championId": "Garen",
                        "role": "top"
                    },
                    {
                        "participantId": 7,
                        "totalGold": 6562,
                        "level": 12,
                        "kills": 0,
                        "deaths": 4,
                        "assists": 2,
                        "creepScore": 130,
                        "currentHealth": 0,
                        "maxHealth": 3639,
                        "esportsPlayerId": "107693484400882014",
                        "summonerName": "ZNT shibi",
                        "championId": "Sejuani",
                        "role": "jungle"
                    },
                    {
                        "participantId": 8,
                        "totalGold": 7519,
                        "level": 12,
                        "kills": 1,
                        "deaths": 7,
                        "assists": 1,
                        "creepScore": 156,
                        "currentHealth": 611,
                        "maxHealth": 2188,
                        "esportsPlayerId": "109146898089227862",
                        "summonerName": "ZNT Marty",
                        "championId": "Neeko",
                        "role": "mid"
                    },
                    {
                        "participantId": 9,
                        "totalGold": 7135,
                        "level": 12,
                        "kills": 0,
                        "deaths": 8,
                        "assists": 2,
                        "creepScore": 168,
                        "currentHealth": 1479,
                        "maxHealth": 1843,
                        "esportsPlayerId": "112458338268604979",
                        "summonerName": "ZNT Afriibi",
                        "championId": "Draven",
                        "role": "bottom"
                    },
                    {
                        "participantId": 10,
                        "totalGold": 5266,
                        "level": 10,
                        "kills": 0,
                        "deaths": 7,
                        "assists": 2,
                        "creepScore": 23,
                        "currentHealth": 630,
                        "maxHealth": 1976,
                        "esportsPlayerId": "110494684110133175",
                        "summonerName": "ZNT J3rkie",
                        "championId": "Renata",
                        "role": "support"
                    }
                ],
                "esportsTeamId": "107128093558481418"
            },
            "esportsGameId": "113990327983174559",
            "esportsMatchId": "113990327983174555"
        }

events = detect_events(frame1, frame2)
print(json.dumps(events, indent=4))
# Out:
# [
#     {
#         "timer": "2025-03-20T19:07:39.902Z",
#         "type": "kill",
#         "team_color": "redTeam",
#         "team_id": "107128093558481418",
#         "player_id": "110467144044264674",
#         "opponent_team_color": "blueTeam",
#         "opponent_team_id": "105515219038427019",
#         "opponent_player_id": "113741971222479798",
#         "game_id": "113990327983174559",
#         "match_id": "113990327983174555"
#     },
#     {
#         "timer": "2025-03-20T19:07:39.902Z",
#         "type": "hextech drake",
#         "team_color": "redTeam",
#         "team_id": "107128093558481418",
#         "player_id": null,
#         "opponent_team_color": "blueTeam",
#         "opponent_team_id": "105515219038427019",
#         "opponent_player_id": null,
#         "game_id": "113990327983174559",
#         "match_id": "113990327983174555"
#     }
# ]

# %%
import requests
import time
import json
from datetime import datetime, timezone, timedelta


API_KEY = "0TvQnueqKa5mxJntVWt0w4LpLfEkrV1Ta8rQBb9Z"  # Remplacez par votre clé API Riot Games
BASE_URL = "https://esports-api.lolesports.com/persisted/gw"
HEADERS = {"x-api-key": API_KEY}





def get_valid_timestamp():
    now = datetime.now(timezone.utc)
    rounded_seconds = now.second - (now.second % 10)  # Arrondi au multiple de 10
    valid_time = now.replace(second=rounded_seconds, microsecond=0)  # Supprime les millisecondes
    
    # Appliquer un décalage de 30 secondes dans le passé
    valid_time -= timedelta(seconds=30)
    
    return valid_time.strftime("%Y-%m-%dT%H:%M:%S.00Z")  # Format ISO avec .00Z




def get_live_events():
    url = f"{BASE_URL}/getLive?hl=fr-FR"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Erreur {response.status_code}: {response.text}")
        return None

def extract_match_info(live_data):
    if not live_data or "data" not in live_data or "schedule" not in live_data["data"]:
        print("Aucune donnée de match en direct trouvée.")
        return
    idMatchTab = []
    idGameTab = []
    events = live_data["data"]["schedule"]["events"]
    for event in events:
        if event.get("state") == "inProgress":
            
            if "match" not in event:
                continue
            #print("event :")
            #print(json.dumps(event, indent=4))
            match_id = event["match"]["id"]
            idMatchTab.append(match_id)
            teams = event["match"]["teams"]
            blue_team = teams[0]["name"]
            red_team = teams[1]["name"]
            #print(f"Match en cours: {blue_team} vs {red_team} (ID: {match_id})")
            games = event["match"]["games"]
            for game in games:
                if game.get("state") == "inProgress":
                    idGameTab.append(game["id"])

                

    return idMatchTab, idGameTab


def get_window_events(game_id, starting_time=None):
    url = f"https://feed.lolesports.com/livestats/v1/window/{game_id}"
    if starting_time:
        url += f"?startingTime={starting_time}"
    
    
    response = requests.get(url, headers=HEADERS)
    
    # Vérifier si le statut HTTP est OK avant de traiter la réponse
    if response.status_code != 200:
        print("pb get_window")
        print(f"Erreur HTTP: {response.status_code}")
        print(response.text)
        print("---")
        return None
    
    # Si la réponse est correcte, tenter de la convertir en JSON
    try:
        return response.json()
    except ValueError as e:
        print(f"Erreur lors de la conversion en JSON: {e}")
        return None

# %%
import time

def main():
    interval = 10  # Intervalle en secondes
    next_run = time.time()
    last_frame = None  # Stocke la dernière frame pour la prochaine itération
    
    while True:
        print("---")
        live_data = get_live_events()
        a, b = extract_match_info(live_data)

        for bb in b:
            st = get_valid_timestamp()
            tmp= get_window_events(bb,st)
            if tmp is not None:
                tmp = ajouter_metadonnees(tmp)
                # Ajouter la dernière frame de l'itération précédente en tête
                if last_frame:
                    tmp["frames"].insert(0, last_frame)
                
                # Mise à jour de la dernière frame pour la prochaine boucle
                if tmp["frames"]:
                    last_frame = tmp["frames"][-1]
                    
                for i in range(len(tmp["frames"]) - 1):
                    event = detect_events(tmp["frames"][i], tmp["frames"][i+1])
                    if event:
                        insert_event(event)
                        print(event)
        

        # Attendre jusqu'à la prochaine itération
        next_run += interval
        time.sleep(max(0, next_run - time.time()))


if __name__ == "__main__":
    main()
# Out:
# ---
# ---
# ---
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 39
#      35         time.sleep(max(0, next_run - time.time()))
#      38 if __name__ == "__main__":
# ---> 39     main()
#
# Cell In[11], line 35, in main()
#      33 # Attendre jusqu'à la prochaine itération
#      34 next_run += interval
# ---> 35 time.sleep(max(0, next_run - time.time()))
#
# KeyboardInterrupt:

# %%
def ajouter_metadonnees(data):
    # Extraction des métadonnées
    blue_team_metadata = data['gameMetadata']['blueTeamMetadata']
    red_team_metadata = data['gameMetadata']['redTeamMetadata']
    esports_game_id = data['esportsGameId']
    esports_match_id = data['esportsMatchId']
    
    # Parcours de chaque frame pour ajouter les métadonnées
    for frame in data['frames']:
        # Ajout des métadonnées de l'équipe bleue
        frame['esportsGameId'] = esports_game_id
        frame['esportsMatchId'] = esports_match_id
        
        for participant in frame['blueTeam']['participants']:
            for blue_participant in blue_team_metadata['participantMetadata']:
                if blue_participant['participantId'] == participant['participantId']:
                    # Intégrer directement les données dans le participant
                    participant.update(blue_participant)
        frame['blueTeam']['esportsTeamId'] = blue_team_metadata['esportsTeamId']
        
        # Ajout des métadonnées de l'équipe rouge
        for participant in frame['redTeam']['participants']:
            for red_participant in red_team_metadata['participantMetadata']:
                if red_participant['participantId'] == participant['participantId']:
                    # Intégrer directement les données dans le participant
                    participant.update(red_participant)
        frame['redTeam']['esportsTeamId'] = red_team_metadata['esportsTeamId']
    
    return data

# Exemple d'utilisation avec les données que tu as fournies
data = {
    'esportsGameId': '113990327983174559',
    'esportsMatchId': '113990327983174555',
    'gameMetadata': {
        'patchVersion': '15.5.662.5311',
        'blueTeamMetadata': {
            'esportsTeamId': '105515219038427019',
            'participantMetadata': [
                {'participantId': 1, 'esportsPlayerId': '105700869624784693', 'summonerName': 'KCB Maynter', 'championId': 'Renekton', 'role': 'top'},
                {'participantId': 2, 'esportsPlayerId': '107464179845128878', 'summonerName': 'KCB ISMA', 'championId': 'Nocturne', 'role': 'jungle'},
                {'participantId': 3, 'esportsPlayerId': '106302003665923326', 'summonerName': 'KCB SlowQ', 'championId': 'Akali', 'role': 'mid'},
                {'participantId': 4, 'esportsPlayerId': '113741971222479798', 'summonerName': 'KCB 3XA', 'championId': 'Aphelios', 'role': 'bottom'},
                {'participantId': 5, 'esportsPlayerId': '109710705987430108', 'summonerName': 'KCB Nsurr', 'championId': 'Karma', 'role': 'support'}
            ]
        },
        'redTeamMetadata': {
            'esportsTeamId': '107128093558481418',
            'participantMetadata': [
                {'participantId': 6, 'esportsPlayerId': '110467144044264674', 'summonerName': 'ZNT Whip', 'championId': 'Garen', 'role': 'top'},
                {'participantId': 7, 'esportsPlayerId': '107693484400882014', 'summonerName': 'ZNT shibi', 'championId': 'Sejuani', 'role': 'jungle'},
                {'participantId': 8, 'esportsPlayerId': '109146898089227862', 'summonerName': 'ZNT Marty', 'championId': 'Neeko', 'role': 'mid'},
                {'participantId': 9, 'esportsPlayerId': '112458338268604979', 'summonerName': 'ZNT Afriibi', 'championId': 'Draven', 'role': 'bottom'},
                {'participantId': 10, 'esportsPlayerId': '110494684110133175', 'summonerName': 'ZNT J3rkie', 'championId': 'Renata', 'role': 'support'}
            ]
        }
    },
    'frames': [
        {'rfc460Timestamp': '2025-03-20T19:07:39.834Z', 'gameState': 'in_game', 'blueTeam': {'totalGold': 53699, 'inhibitors': 1, 'towers': 10, 'barons': 0, 'totalKills': 30, 'dragons': ['mountain', 'chemtech'], 'participants': [{'participantId': 1, 'totalGold': 11869, 'level': 16, 'kills': 4, 'deaths': 0, 'assists': 4, 'creepScore': 233, 'currentHealth': 2383, 'maxHealth': 3893}, {'participantId': 2, 'totalGold': 11326, 'level': 14, 'kills': 12, 'deaths': 1, 'assists': 10, 'creepScore': 147, 'currentHealth': 0, 'maxHealth': 2962}, {'participantId': 3, 'totalGold': 10461, 'level': 15, 'kills': 7, 'deaths': 1, 'assists': 7, 'creepScore': 204, 'currentHealth': 1725, 'maxHealth': 2844}, {'participantId': 4, 'totalGold': 12850, 'level': 15, 'kills': 7, 'deaths': 0, 'assists': 16, 'creepScore': 231, 'currentHealth': 2183, 'maxHealth': 2183}, {'participantId': 5, 'totalGold': 7193, 'level': 12, 'kills': 0, 'deaths': 1, 'assists': 26, 'creepScore': 19, 'currentHealth': 1595, 'maxHealth': 2368}]}, 'redTeam': {'totalGold': 36302, 'inhibitors': 0, 'towers': 1, 'barons': 0, 'totalKills': 3, 'dragons': ['cloud'], 'participants': [{'participantId': 6, 'totalGold': 9820, 'level': 14, 'kills': 2, 'deaths': 4, 'assists': 1, 'creepScore': 195, 'currentHealth': 0, 'maxHealth': 2770}, {'participantId': 7, 'totalGold': 6562, 'level': 12, 'kills': 0, 'deaths': 4, 'assists': 2, 'creepScore': 130, 'currentHealth': 0, 'maxHealth': 3639}, {'participantId': 8, 'totalGold': 7519, 'level': 12, 'kills': 1, 'deaths': 7, 'assists': 1, 'creepScore': 156, 'currentHealth': 611, 'maxHealth': 2188}, {'participantId': 9, 'totalGold': 7135, 'level': 12, 'kills': 0, 'deaths': 8, 'assists': 2, 'creepScore': 168, 'currentHealth': 1479, 'maxHealth': 1843}, {'participantId': 10, 'totalGold': 5266, 'level': 10, 'kills': 0, 'deaths': 7, 'assists': 2, 'creepScore': 23, 'currentHealth': 630, 'maxHealth': 1976}]}}
    ]
}

data_avec_metadonnees = ajouter_metadonnees(get_window(113990327983174559,get_valid_timestamp()))


print(json.dumps(data_avec_metadonnees, indent=4))
# Out:
# 200
# {
#     "esportsGameId": "113990327983174559",
#     "esportsMatchId": "113990327983174555",
#     "gameMetadata": {
#         "patchVersion": "15.5.662.5311",
#         "blueTeamMetadata": {
#             "esportsTeamId": "105515219038427019",
#             "participantMetadata": [
#                 {
#                     "participantId": 1,
#                     "esportsPlayerId": "105700869624784693",
#                     "summonerName": "KCB Maynter",
#                     "championId": "Renekton",
#                     "role": "top"
#                 },
#                 {
#                     "participantId": 2,
#                     "esportsPlayerId": "107464179845128878",
#                     "summonerName": "KCB ISMA",
#                     "championId": "Nocturne",
#                     "role": "jungle"
#                 },
#                 {
#                     "participantId": 3,
#                     "esportsPlayerId": "106302003665923326",
#                     "summonerName": "KCB SlowQ",
#                     "championId": "Akali",
#                     "role": "mid"
#                 },
#                 {
#                     "participantId": 4,
#                     "esportsPlayerId": "113741971222479798",
#                     "summonerName": "KCB 3XA",
#                     "championId": "Aphelios",
#                     "role": "bottom"
#                 },
#                 {
#                     "participantId": 5,
#                     "esportsPlayerId": "109710705987430108",
#                     "summonerName": "KCB Nsurr",
#                     "championId": "Karma",
#                     "role": "support"
#                 }
#             ]
#         },
#         "redTeamMetadata": {
#             "esportsTeamId": "107128093558481418",
#             "participantMetadata": [
#                 {
#                     "participantId": 6,
#                     "esportsPlayerId": "110467144044264674",
#                     "summonerName": "ZNT Whip",
#                     "championId": "Garen",
#                     "role": "top"
#                 },
#                 {
#                     "participantId": 7,
#                     "esportsPlayerId": "107693484400882014",
#                     "summonerName": "ZNT shibi",
#                     "championId": "Sejuani",
#                     "role": "jungle"
#                 },
#                 {
#                     "participantId": 8,
#                     "esportsPlayerId": "109146898089227862",
#                     "summonerName": "ZNT Marty",
#                     "championId": "Neeko",
#                     "role": "mid"
#                 },
#                 {
#                     "participantId": 9,
#                     "esportsPlayerId": "112458338268604979",
#                     "summonerName": "ZNT Afriibi",
#                     "championId": "Draven",
#                     "role": "bottom"
#                 },
#                 {
#                     "participantId": 10,
#                     "esportsPlayerId": "110494684110133175",
#                     "summonerName": "ZNT J3rkie",
#                     "championId": "Renata",
#                     "role": "support"
#                 }
#             ]
#         }
#     },
#     "frames": [
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:39.834Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53699,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11869,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2383,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11326,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10461,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1725,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12850,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7193,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1595,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36302,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9820,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6562,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7519,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 611,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7135,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1479,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5266,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 630,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:39.902Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53699,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11869,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2383,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11326,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10461,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1725,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12850,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7193,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1595,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36302,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9820,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6562,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7519,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 611,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7135,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1479,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5266,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 630,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:39.906Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53699,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11869,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2383,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11326,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10461,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1725,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12850,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7193,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1595,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36302,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9820,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6562,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7519,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 611,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7135,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1479,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5266,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 630,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:40.001Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53699,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11869,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2383,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11326,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10461,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1725,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12850,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7193,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1595,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36302,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9820,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6562,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7519,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 611,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7135,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1479,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5266,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 630,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:40.736Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53710,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11871,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2390,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11328,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10463,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1734,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12852,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7196,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1599,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36312,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9822,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6564,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7521,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 671,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7137,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1529,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5268,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 690,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:41.603Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53710,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11871,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2390,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11328,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10463,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1734,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12852,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7196,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1599,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36312,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9822,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6564,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7521,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 671,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7137,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1529,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5268,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 690,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:41.739Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53720,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11873,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2398,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11330,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
# ...
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7141,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1533,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5274,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 708,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:43.645Z",
#             "gameState": "in_game",
#             "blueTeam": {
#                 "totalGold": 53741,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11877,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2413,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11334,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10469,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1760,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12858,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7203,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1611,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36344,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9828,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6570,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7527,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 680,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7143,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1535,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5276,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 717,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         },
#         {
#             "rfc460Timestamp": "2025-03-20T19:07:43.646Z",
#             "gameState": "finished",
#             "blueTeam": {
#                 "totalGold": 53741,
#                 "inhibitors": 1,
#                 "towers": 10,
#                 "barons": 0,
#                 "totalKills": 30,
#                 "dragons": [
#                     "mountain",
#                     "chemtech"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 1,
#                         "totalGold": 11877,
#                         "level": 16,
#                         "kills": 4,
#                         "deaths": 0,
#                         "assists": 4,
#                         "creepScore": 233,
#                         "currentHealth": 2413,
#                         "maxHealth": 3893,
#                         "esportsPlayerId": "105700869624784693",
#                         "summonerName": "KCB Maynter",
#                         "championId": "Renekton",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 2,
#                         "totalGold": 11334,
#                         "level": 14,
#                         "kills": 12,
#                         "deaths": 1,
#                         "assists": 10,
#                         "creepScore": 147,
#                         "currentHealth": 0,
#                         "maxHealth": 2962,
#                         "esportsPlayerId": "107464179845128878",
#                         "summonerName": "KCB ISMA",
#                         "championId": "Nocturne",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 3,
#                         "totalGold": 10469,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 1,
#                         "assists": 7,
#                         "creepScore": 204,
#                         "currentHealth": 1760,
#                         "maxHealth": 2844,
#                         "esportsPlayerId": "106302003665923326",
#                         "summonerName": "KCB SlowQ",
#                         "championId": "Akali",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 4,
#                         "totalGold": 12858,
#                         "level": 15,
#                         "kills": 7,
#                         "deaths": 0,
#                         "assists": 16,
#                         "creepScore": 231,
#                         "currentHealth": 2183,
#                         "maxHealth": 2183,
#                         "esportsPlayerId": "113741971222479798",
#                         "summonerName": "KCB 3XA",
#                         "championId": "Aphelios",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 5,
#                         "totalGold": 7203,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 1,
#                         "assists": 26,
#                         "creepScore": 19,
#                         "currentHealth": 1611,
#                         "maxHealth": 2368,
#                         "esportsPlayerId": "109710705987430108",
#                         "summonerName": "KCB Nsurr",
#                         "championId": "Karma",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "105515219038427019"
#             },
#             "redTeam": {
#                 "totalGold": 36344,
#                 "inhibitors": 0,
#                 "towers": 1,
#                 "barons": 0,
#                 "totalKills": 3,
#                 "dragons": [
#                     "cloud"
#                 ],
#                 "participants": [
#                     {
#                         "participantId": 6,
#                         "totalGold": 9828,
#                         "level": 14,
#                         "kills": 2,
#                         "deaths": 4,
#                         "assists": 1,
#                         "creepScore": 195,
#                         "currentHealth": 0,
#                         "maxHealth": 2770,
#                         "esportsPlayerId": "110467144044264674",
#                         "summonerName": "ZNT Whip",
#                         "championId": "Garen",
#                         "role": "top"
#                     },
#                     {
#                         "participantId": 7,
#                         "totalGold": 6570,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 4,
#                         "assists": 2,
#                         "creepScore": 130,
#                         "currentHealth": 0,
#                         "maxHealth": 3639,
#                         "esportsPlayerId": "107693484400882014",
#                         "summonerName": "ZNT shibi",
#                         "championId": "Sejuani",
#                         "role": "jungle"
#                     },
#                     {
#                         "participantId": 8,
#                         "totalGold": 7527,
#                         "level": 12,
#                         "kills": 1,
#                         "deaths": 7,
#                         "assists": 1,
#                         "creepScore": 156,
#                         "currentHealth": 680,
#                         "maxHealth": 2188,
#                         "esportsPlayerId": "109146898089227862",
#                         "summonerName": "ZNT Marty",
#                         "championId": "Neeko",
#                         "role": "mid"
#                     },
#                     {
#                         "participantId": 9,
#                         "totalGold": 7143,
#                         "level": 12,
#                         "kills": 0,
#                         "deaths": 8,
#                         "assists": 2,
#                         "creepScore": 168,
#                         "currentHealth": 1535,
#                         "maxHealth": 1843,
#                         "esportsPlayerId": "112458338268604979",
#                         "summonerName": "ZNT Afriibi",
#                         "championId": "Draven",
#                         "role": "bottom"
#                     },
#                     {
#                         "participantId": 10,
#                         "totalGold": 5276,
#                         "level": 10,
#                         "kills": 0,
#                         "deaths": 7,
#                         "assists": 2,
#                         "creepScore": 23,
#                         "currentHealth": 717,
#                         "maxHealth": 1976,
#                         "esportsPlayerId": "110494684110133175",
#                         "summonerName": "ZNT J3rkie",
#                         "championId": "Renata",
#                         "role": "support"
#                     }
#                 ],
#                 "esportsTeamId": "107128093558481418"
#             },
#             "esportsGameId": "113990327983174559",
#             "esportsMatchId": "113990327983174555"
#         }
#     ]
# }

# %%
import mysql.connector
import json
from datetime import datetime

db_config = {
    "host": "localhost",
    "user": "root",
    "password": "root",
    "database": "play_by_play"
}

def insert_event(event_json):
    try:
        # Connexion à la base de données
        conn = mysql.connector.connect(**db_config)
        cursor = conn.cursor()
        
        # Requête d'insertion
        query = """
        INSERT INTO event (event_time, type, team_color, team_id, player_id, 
                            opponent_team_color, opponent_team_id, opponent_player_id, 
                            game_id, match_id) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        
        # Extraction des valeurs du JSON
        values = (
            datetime.strptime(event_json["timer"], "%Y-%m-%dT%H:%M:%S.%fZ").strftime("%Y-%m-%d %H:%M:%S"), event_json["type"], event_json["team_color"], event_json["team_id"],
            event_json["player_id"], event_json["opponent_team_color"], event_json["opponent_team_id"],
            event_json["opponent_player_id"], event_json["game_id"], event_json["match_id"]
        )
        
        # Exécution de la requête
        cursor.execute(query, values)
        conn.commit()
        print("Événement inséré avec succès !")
        
    except mysql.connector.Error as err:
        print("Erreur MySQL:", err)
    finally:
        cursor.close()
        conn.close()

# %%
event_data = {
    "timer": "2025-03-20T19:07:39.902Z",
    "type": "kill",
    "team_color": "redTeam",
    "team_id": "107128093558481418",
    "player_id": "110467144044264674",
    "opponent_team_color": "blueTeam",
    "opponent_team_id": "105515219038427019",
    "opponent_player_id": "113741971222479798",
    "game_id": "113990327983174559",
    "match_id": "113990327983174555"
}

insert_event(event_data)
# Out:
# Événement inséré avec succès !
